# %%
import pandas as pd

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
os.path.abspath("..")
# Out:
# 'C:\\Users\\DELL\\surakshit_tasks\\software projects\\bank_marketing'

# %%
from src.pipeline.predict_pipeline import PredictPipeline

# %%
PredictPipeline
# Out:
# src.pipeline.predict_pipeline.PredictPipeline

# %%
customer_data = {
            "age":35,
            "occupation": "management",
            "marital_status": "married",
            "education_level" :"tertiary",
            
            "communication_channel" : "mobile",
            "call_day" : 5,
            "call_month" : "May",
            "call_duration"  : 180,
            "call_frequency" : 2,
            "previous_campaign_outcome": "unknown"
}

# %%
import pandas as pd

input_df = pd.DataFrame([customer_data])

# %%
pipeline = PredictPipeline()

prediction, probability = pipeline.predict(input_df)

print(prediction, probability)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\surakshit_tasks\software projects\bank_marketing\src\pipeline\predict_pipeline.py:20, in PredictPipeline.__init__(self)
#      18 artifacts_dir = "artifacts"
# ---> 20 self.model = load_object(os.path.join(artifacts_dir, "best_model.pkl"))
#      21 self.encoder = load_object(os.path.join(artifacts_dir, "encoder.pkl"))
#
# File ~\surakshit_tasks\software projects\bank_marketing\src\utils\file_ops.py:9, in load_object(path)
#       8 def load_object(path):
# ----> 9     with open(path, "rb") as f:
#      10         return pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'artifacts\\best_model.pkl'
#
# During handling of the above exception, another exception occurred:
#
# CustomException                           Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pipeline = PredictPipeline()
#       3 prediction, probability = pipeline.predict(input_df)
#       5 print(prediction, probability)
#
# File ~\surakshit_tasks\software projects\bank_marketing\src\pipeline\predict_pipeline.py:26, in PredictPipeline.__init__(self)
#      23     self.label_encoder = load_object(os.path.join(artifacts_dir, "label_encoder.pkl"))
#      25 except Exception as e:
# ---> 26     raise CustomException(e, sys)
#
# CustomException: Error in [C:\Users\DELL\surakshit_tasks\software projects\bank_marketing\src\pipeline\predict_pipeline.py] at line [20] : [Errno 2] No such file or directory: 'artifacts\\best_model.pkl'
